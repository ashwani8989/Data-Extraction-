# %% [markdown]
# # Data Extraction Assignment

# %% [markdown]
# 1- Describe different types of data sources used in ETL with suitable examples.
#
# Ans--ETL systems pull data from multiple data pletfroms sources, ensuring that both structured and unstructured data can be integrated into a central data warehouse for analysis.
# exmp- SQL, Exel, oracle, api etc..
#
# Q2. What is data extraction? Explain its role in the ETL pipeline.
# Ans-- Data extraction first step in etl prosses in data wearhouing, it is the prosses of retrieving data from different sources such as databases, files, APIs, or applications, data in a usable format for further processing.
#
# Q3.  Explain the difference between CSV and Excel in terms of extraction and ETL usage.
# Ans-- CSV and Excel both are commen data sureces for ETL.
# CVS Lightweight and fast to process and Easy to parse by any programming language or ETL tool
# Exel are formatting, formulas, and multiple worksheets and More complex to CSV.
#
# Q4. Explain the steps involved in extracting data from a relational database.
# Ans-- Extracting data from a relational database is first step in ETL. It involves systematically retrieving the required data so it can be transformed and loaded for analysis.
# Data Extracting step-- identify data soures, select data extract method, excute extraction, data filtring and validition, last data store.
#
# Q5. Explain three common challenges faced during data extraction.
# Ans-- During the data extraction faced many issued.
# 1- face difficlt to standardize extraction across systems.
# 2-system compatibility issues, 3- large data and performence issue, and data quilet issues.. etc
#
# Q6. What are APIs? Explain how APIs help in real-time data extraction
# Ans-- APIs are tools that allow different software systems to communicate and exchange data with each other. and APIS help for Data usually exchanged in json.
#
# Q7. Why are databases preferred for enterprise-level data extraction.
# Ans-- Databases are preferred for enterprise-level data extraction in ETL within data warehousing because they provide reliability. and databases are ideal for enterprise-level extraction because they provide a robust, secure, and efficient environment to handle large and complex datasets
#
# Q8.What steps should an ETL developer take when extracting data from large CSV files (1GB+).
# Ans-- Efficient extraction from large CSV files requires a combination of memory management, performance optimization, and robust error handling to ensure smooth ETL execution.
